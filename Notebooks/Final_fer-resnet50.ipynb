# %% [markdown]
# # **Dataset & Description**
#
#
#
# [![image.png](attachment:image.png)](http://)
#
#
# The data consists of 48x48 pixel grayscale images of faces. The faces have been automatically registered so that the face is more or less centred and occupies about the same amount of space in each image.
#
# The task is to categorize each face based on the emotion shown in the facial expression into one of seven categories (0=Angry, 1=Disgust, 2=Fear, 3=Happy, 4=Sad, 5=Surprise, 6=Neutral). The training set consists of 28,709 examples and the public test set consists of 3,589 examples.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn
import skimage.io
import keras.backend as K
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.layers import Dense, Flatten, Dropout,BatchNormalization ,Activation
from tensorflow.keras.models import Model, Sequential
from keras.applications.nasnet import NASNetLarge
from tensorflow.keras.callbacks import ReduceLROnPlateau, ModelCheckpoint, EarlyStopping
from tensorflow.keras.optimizers import Adam

# %%
train_datagen = ImageDataGenerator(rescale = 1./255,
                                   validation_split = 0.2,
                                  
        rotation_range=5,
        width_shift_range=0.2,
        height_shift_range=0.2,
        shear_range=0.2,
        #zoom_range=0.2,
        horizontal_flip=True,
        vertical_flip=True,
        fill_mode='nearest')

valid_datagen = ImageDataGenerator(rescale = 1./255,
                                  validation_split = 0.2)

test_datagen  = ImageDataGenerator(rescale = 1./255
                                  )

# %%
train_dataset  = train_datagen.flow_from_directory(directory = '../input/fer2013/train',
                                                   target_size = (48,48),
                                                   class_mode = 'categorical',
                                                   subset = 'training',
                                                   batch_size = 64)
# Out:
# Found 22968 images belonging to 7 classes.

# %%
valid_dataset = valid_datagen.flow_from_directory(directory = '../input/fer2013/train',
                                                  target_size = (48,48),
                                                  class_mode = 'categorical',
                                                  subset = 'validation',
                                                  batch_size = 64)
# Out:
# Found 5741 images belonging to 7 classes.

# %%
test_dataset = test_datagen.flow_from_directory(directory = '../input/fer2013/test',
                                                  target_size = (48,48),
                                                  class_mode = 'categorical',
                                                  batch_size = 64)
# Out:
# Found 7178 images belonging to 7 classes.

# %%
test_dataset

# %%
from keras.preprocessing import image
img = image.load_img("../input/fer2013/test/angry/PrivateTest_10131363.jpg",target_size=(48,48))
img = np.array(img)
plt.imshow(img)
print(img.shape)

img = np.expand_dims(img, axis=0)
from keras.models import load_model
print(img.shape)
# Out:
# (48, 48, 3)
# (1, 48, 48, 3)

# %%
base_model = tf.keras.applications.ResNet50(input_shape=(48,48,3),include_top=False,weights="imagenet")

# %%
# Freezing Layers

for layer in base_model.layers[:-4]:
    layer.trainable=False

# %%
# Building Model

model=Sequential()
model.add(base_model)
model.add(Dropout(0.5))
model.add(Flatten())
model.add(BatchNormalization())
model.add(Dense(32,kernel_initializer='he_uniform'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(32,kernel_initializer='he_uniform'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(32,kernel_initializer='he_uniform'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dense(7,activation='softmax'))

# %%
# Model Summary

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# resnet50 (Functional)        (None, 2, 2, 2048)        23587712
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 2, 2, 2048)        0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 8192)              0
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 8192)              32768
# _________________________________________________________________
# dense_4 (Dense)              (None, 32)                262176
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 32)                128
# _________________________________________________________________
# activation_3 (Activation)    (None, 32)                0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_5 (Dense)              (None, 32)                1056
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 32)                128
# _________________________________________________________________
# activation_4 (Activation)    (None, 32)                0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_6 (Dense)              (None, 32)                1056
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 32)                128
# _________________________________________________________________
# activation_5 (Activation)    (None, 32)                0
# _________________________________________________________________
# dense_7 (Dense)              (None, 7)                 231
# =================================================================
# Total params: 23,885,383
# Trainable params: 1,335,815
# Non-trainable params: 22,549,568
# _________________________________________________________________

# %%
from tensorflow.keras.utils import plot_model
from IPython.display import Image
plot_model(model, to_file='convnet.png', show_shapes=True,show_layer_names=True)
Image(filename='convnet.png')

# %%
def f1_score(y_true, y_pred): #taken from old keras source code
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    recall = true_positives / (possible_positives + K.epsilon())
    f1_val = 2*(precision*recall)/(precision+recall+K.epsilon())
    return f1_val

# %%
METRICS = [
      tf.keras.metrics.BinaryAccuracy(name='accuracy'),
      tf.keras.metrics.Precision(name='precision'),
      tf.keras.metrics.Recall(name='recall'),  
      tf.keras.metrics.AUC(name='auc'),
        f1_score,
]

# %%
lrd = ReduceLROnPlateau(monitor = 'val_loss',patience = 20,verbose = 1,factor = 0.50, min_lr = 1e-10)

mcp = ModelCheckpoint('model.h5')

es = EarlyStopping(verbose=1, patience=20)

# %%
model.compile(optimizer='Adam', loss='categorical_crossentropy',metrics=METRICS)

# %%
history=model.fit(train_dataset,validation_data=valid_dataset,epochs = 50,verbose = 1,callbacks=[lrd,mcp,es])
# Out:
# Epoch 1/50
# 359/359 [==============================] - 45s 125ms/step - loss: 1.8213 - accuracy: 0.8571 - precision: 0.4444 - recall: 3.4831e-04 - auc: 0.6405 - f1_score: 6.8567e-04 - val_loss: 1.8143 - val_accuracy: 0.8571 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.6500 - val_f1_score: 0.0000e+00
# Epoch 2/50
# 359/359 [==============================] - 44s 123ms/step - loss: 1.8175 - accuracy: 0.8571 - precision: 0.1250 - recall: 4.3539e-05 - auc: 0.6406 - f1_score: 8.5708e-05 - val_loss: 1.8081 - val_accuracy: 0.8571 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.6571 - val_f1_score: 0.0000e+00
# Epoch 3/50
# 359/359 [==============================] - 43s 120ms/step - loss: 1.8138 - accuracy: 0.8571 - precision: 0.0000e+00 - recall: 0.0000e+00 - auc: 0.6439 - f1_score: 0.0000e+00 - val_loss: 1.8059 - val_accuracy: 0.8571 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.6565 - val_f1_score: 0.0000e+00
# Epoch 4/50
# 359/359 [==============================] - 43s 121ms/step - loss: 1.8113 - accuracy: 0.8571 - precision: 0.0000e+00 - recall: 0.0000e+00 - auc: 0.6453 - f1_score: 0.0000e+00 - val_loss: 1.8022 - val_accuracy: 0.8572 - val_precision: 1.0000 - val_recall: 1.7419e-04 - val_auc: 0.6593 - val_f1_score: 3.4188e-04
# Epoch 5/50
# 359/359 [==============================] - 44s 121ms/step - loss: 1.8095 - accuracy: 0.8571 - precision: 0.0000e+00 - recall: 0.0000e+00 - auc: 0.6464 - f1_score: 0.0000e+00 - val_loss: 1.7980 - val_accuracy: 0.8571 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.6607 - val_f1_score: 0.0000e+00
# Epoch 6/50
# 359/359 [==============================] - 44s 122ms/step - loss: 1.8064 - accuracy: 0.8571 - precision: 0.0000e+00 - recall: 0.0000e+00 - auc: 0.6492 - f1_score: 0.0000e+00 - val_loss: 1.7956 - val_accuracy: 0.8571 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.6596 - val_f1_score: 0.0000e+00
# Epoch 7/50
# 359/359 [==============================] - 43s 120ms/step - loss: 1.8039 - accuracy: 0.8571 - precision: 0.0000e+00 - recall: 0.0000e+00 - auc: 0.6507 - f1_score: 0.0000e+00 - val_loss: 1.7907 - val_accuracy: 0.8571 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.6646 - val_f1_score: 0.0000e+00
# Epoch 8/50
# 359/359 [==============================] - 43s 119ms/step - loss: 1.8029 - accuracy: 0.8571 - precision: 0.0000e+00 - recall: 0.0000e+00 - auc: 0.6534 - f1_score: 0.0000e+00 - val_loss: 1.7996 - val_accuracy: 0.8571 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.6603 - val_f1_score: 0.0000e+00
# Epoch 9/50
# 359/359 [==============================] - 43s 120ms/step - loss: 1.8018 - accuracy: 0.8571 - precision: 0.0000e+00 - recall: 0.0000e+00 - auc: 0.6538 - f1_score: 0.0000e+00 - val_loss: 1.7865 - val_accuracy: 0.8571 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.6704 - val_f1_score: 0.0000e+00
# Epoch 10/50
# 359/359 [==============================] - 43s 121ms/step - loss: 1.8022 - accuracy: 0.8571 - precision: 0.0000e+00 - recall: 0.0000e+00 - auc: 0.6536 - f1_score: 0.0000e+00 - val_loss: 1.7983 - val_accuracy: 0.8571 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.6656 - val_f1_score: 0.0000e+00
# Epoch 11/50
# 359/359 [==============================] - 43s 120ms/step - loss: 1.7988 - accuracy: 0.8571 - precision: 0.0000e+00 - recall: 0.0000e+00 - auc: 0.6563 - f1_score: 0.0000e+00 - val_loss: 1.7818 - val_accuracy: 0.8571 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.6754 - val_f1_score: 0.0000e+00
# Epoch 12/50
# 359/359 [==============================] - 43s 120ms/step - loss: 1.7970 - accuracy: 0.8572 - precision: 1.0000 - recall: 4.3539e-05 - auc: 0.6582 - f1_score: 8.5708e-05 - val_loss: 1.7967 - val_accuracy: 0.8571 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.6640 - val_f1_score: 0.0000e+00
# Epoch 13/50
# 359/359 [==============================] - 43s 118ms/step - loss: 1.7968 - accuracy: 0.8571 - precision: 0.0000e+00 - recall: 0.0000e+00 - auc: 0.6589 - f1_score: 0.0000e+00 - val_loss: 1.7797 - val_accuracy: 0.8571 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.6746 - val_f1_score: 0.0000e+00
# Epoch 14/50
# 359/359 [==============================] - 44s 123ms/step - loss: 1.7955 - accuracy: 0.8571 - precision: 0.0000e+00 - recall: 0.0000e+00 - auc: 0.6594 - f1_score: 0.0000e+00 - val_loss: 1.7767 - val_accuracy: 0.8571 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.6783 - val_f1_score: 0.0000e+00
# Epoch 15/50
# 359/359 [==============================] - 43s 121ms/step - loss: 1.7940 - accuracy: 0.8571 - precision: 0.0000e+00 - recall: 0.0000e+00 - auc: 0.6608 - f1_score: 0.0000e+00 - val_loss: 1.7795 - val_accuracy: 0.8571 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.6740 - val_f1_score: 0.0000e+00
# Epoch 16/50
# 359/359 [==============================] - 44s 123ms/step - loss: 1.7906 - accuracy: 0.8571 - precision: 0.0000e+00 - recall: 0.0000e+00 - auc: 0.6638 - f1_score: 0.0000e+00 - val_loss: 1.7976 - val_accuracy: 0.8571 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.6680 - val_f1_score: 0.0000e+00
# Epoch 17/50
# 359/359 [==============================] - 44s 122ms/step - loss: 1.7903 - accuracy: 0.8572 - precision: 0.7500 - recall: 1.3062e-04 - auc: 0.6648 - f1_score: 2.5712e-04 - val_loss: 1.7715 - val_accuracy: 0.8571 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.6819 - val_f1_score: 0.0000e+00
# Epoch 18/50
# 359/359 [==============================] - 44s 124ms/step - loss: 1.7894 - accuracy: 0.8571 - precision: 0.5000 - recall: 4.3539e-05 - auc: 0.6643 - f1_score: 8.5708e-05 - val_loss: 1.7829 - val_accuracy: 0.8571 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.6723 - val_f1_score: 0.0000e+00
# Epoch 19/50
# 359/359 [==============================] - 44s 122ms/step - loss: 1.7893 - accuracy: 0.8572 - precision: 1.0000 - recall: 4.3539e-05 - auc: 0.6656 - f1_score: 8.5708e-05 - val_loss: 1.7747 - val_accuracy: 0.8571 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.6773 - val_f1_score: 0.0000e+00
# Epoch 20/50
# 359/359 [==============================] - 43s 120ms/step - loss: 1.7883 - accuracy: 0.8571 - precision: 0.5000 - recall: 8.7078e-05 - auc: 0.6653 - f1_score: 1.7142e-04 - val_loss: 1.7664 - val_accuracy: 0.8571 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.6845 - val_f1_score: 0.0000e+00
# Epoch 21/50
# 359/359 [==============================] - 44s 121ms/step - loss: 1.7876 - accuracy: 0.8571 - precision: 0.0000e+00 - recall: 0.0000e+00 - auc: 0.6675 - f1_score: 0.0000e+00 - val_loss: 1.7733 - val_accuracy: 0.8571 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.6782 - val_f1_score: 0.0000e+00
# Epoch 22/50
# 359/359 [==============================] - 43s 119ms/step - loss: 1.7857 - accuracy: 0.8572 - precision: 0.5714 - recall: 1.7416e-04 - auc: 0.6681 - f1_score: 3.4283e-04 - val_loss: 1.7792 - val_accuracy: 0.8571 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.6745 - val_f1_score: 0.0000e+00
# Epoch 23/50
# 359/359 [==============================] - 43s 121ms/step - loss: 1.7856 - accuracy: 0.8571 - precision: 0.0000e+00 - recall: 0.0000e+00 - auc: 0.6680 - f1_score: 0.0000e+00 - val_loss: 1.7751 - val_accuracy: 0.8571 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.6784 - val_f1_score: 0.0000e+00
# Epoch 24/50
# 359/359 [==============================] - 43s 119ms/step - loss: 1.7843 - accuracy: 0.8571 - precision: 0.4000 - recall: 8.7078e-05 - auc: 0.6697 - f1_score: 1.7142e-04 - val_loss: 1.7600 - val_accuracy: 0.8571 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.6905 - val_f1_score: 0.0000e+00
# Epoch 25/50
# 359/359 [==============================] - 43s 119ms/step - loss: 1.7836 - accuracy: 0.8571 - precision: 0.3889 - recall: 3.0477e-04 - auc: 0.6692 - f1_score: 5.9996e-04 - val_loss: 1.7706 - val_accuracy: 0.8571 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.6830 - val_f1_score: 0.0000e+00
# Epoch 26/50
# 359/359 [==============================] - 43s 119ms/step - loss: 1.7818 - accuracy: 0.8571 - precision: 0.3750 - recall: 2.6123e-04 - auc: 0.6707 - f1_score: 5.1425e-04 - val_loss: 1.7626 - val_accuracy: 0.8571 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.6877 - val_f1_score: 0.0000e+00
# Epoch 27/50
# 359/359 [==============================] - 44s 121ms/step - loss: 1.7847 - accuracy: 0.8572 - precision: 0.5294 - recall: 3.9185e-04 - auc: 0.6692 - f1_score: 7.7137e-04 - val_loss: 1.7607 - val_accuracy: 0.8571 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.6896 - val_f1_score: 0.0000e+00
# Epoch 28/50
# 359/359 [==============================] - 43s 121ms/step - loss: 1.7813 - accuracy: 0.8571 - precision: 0.4706 - recall: 3.4831e-04 - auc: 0.6713 - f1_score: 6.8567e-04 - val_loss: 1.7596 - val_accuracy: 0.8571 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.6889 - val_f1_score: 0.0000e+00
# Epoch 29/50
# 359/359 [==============================] - 43s 121ms/step - loss: 1.7788 - accuracy: 0.8571 - precision: 0.3200 - recall: 3.4831e-04 - auc: 0.6735 - f1_score: 6.8567e-04 - val_loss: 1.7591 - val_accuracy: 0.8571 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.6889 - val_f1_score: 0.0000e+00
# Epoch 30/50
# 359/359 [==============================] - 43s 119ms/step - loss: 1.7816 - accuracy: 0.8572 - precision: 0.5714 - recall: 5.2247e-04 - auc: 0.6710 - f1_score: 0.0010 - val_loss: 1.7573 - val_accuracy: 0.8571 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.6909 - val_f1_score: 0.0000e+00
# Epoch 31/50
# 359/359 [==============================] - 43s 119ms/step - loss: 1.7790 - accuracy: 0.8571 - precision: 0.4444 - recall: 3.4831e-04 - auc: 0.6724 - f1_score: 6.8567e-04 - val_loss: 1.7614 - val_accuracy: 0.8573 - val_precision: 1.0000 - val_recall: 0.0010 - val_auc: 0.6913 - val_f1_score: 0.0021
# Epoch 32/50
# 359/359 [==============================] - 43s 120ms/step - loss: 1.7784 - accuracy: 0.8572 - precision: 0.6000 - recall: 3.9185e-04 - auc: 0.6731 - f1_score: 7.7137e-04 - val_loss: 1.7473 - val_accuracy: 0.8571 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.6964 - val_f1_score: 0.0000e+00
# Epoch 33/50
# 359/359 [==============================] - 44s 124ms/step - loss: 1.7768 - accuracy: 0.8572 - precision: 0.6875 - recall: 4.7893e-04 - auc: 0.6742 - f1_score: 9.4019e-04 - val_loss: 1.7619 - val_accuracy: 0.8571 - val_precision: 0.5000 - val_recall: 1.7419e-04 - val_auc: 0.6882 - val_f1_score: 3.4188e-04
# Epoch 34/50
# 359/359 [==============================] - 44s 124ms/step - loss: 1.7769 - accuracy: 0.8572 - precision: 0.5455 - recall: 5.2247e-04 - auc: 0.6747 - f1_score: 0.0010 - val_loss: 1.7620 - val_accuracy: 0.8571 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.6863 - val_f1_score: 0.0000e+00
# Epoch 35/50
# 359/359 [==============================] - 43s 120ms/step - loss: 1.7765 - accuracy: 0.8572 - precision: 0.5238 - recall: 4.7893e-04 - auc: 0.6748 - f1_score: 9.4279e-04 - val_loss: 1.7560 - val_accuracy: 0.8571 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.6909 - val_f1_score: 0.0000e+00
# Epoch 36/50
# 359/359 [==============================] - 44s 122ms/step - loss: 1.7745 - accuracy: 0.8572 - precision: 0.5263 - recall: 4.3539e-04 - auc: 0.6766 - f1_score: 8.5578e-04 - val_loss: 1.7499 - val_accuracy: 0.8571 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.6943 - val_f1_score: 0.0000e+00
# Epoch 37/50
# 359/359 [==============================] - 43s 119ms/step - loss: 1.7739 - accuracy: 0.8571 - precision: 0.4688 - recall: 0.0013 - auc: 0.6770 - f1_score: 0.0026 - val_loss: 1.7615 - val_accuracy: 0.8571 - val_precision: 0.2000 - val_recall: 1.7419e-04 - val_auc: 0.6888 - val_f1_score: 3.4188e-04
# Epoch 38/50
# 359/359 [==============================] - 43s 121ms/step - loss: 1.7752 - accuracy: 0.8572 - precision: 0.5893 - recall: 0.0014 - auc: 0.6757 - f1_score: 0.0028 - val_loss: 1.7847 - val_accuracy: 0.8573 - val_precision: 0.6250 - val_recall: 0.0035 - val_auc: 0.6789 - val_f1_score: 0.0068
# Epoch 39/50
# 359/359 [==============================] - 44s 123ms/step - loss: 1.7726 - accuracy: 0.8572 - precision: 0.5231 - recall: 0.0015 - auc: 0.6777 - f1_score: 0.0029 - val_loss: 1.7437 - val_accuracy: 0.8571 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.6982 - val_f1_score: 0.0000e+00
# Epoch 40/50
# 359/359 [==============================] - 43s 121ms/step - loss: 1.7752 - accuracy: 0.8571 - precision: 0.3600 - recall: 3.9185e-04 - auc: 0.6761 - f1_score: 7.7137e-04 - val_loss: 1.7533 - val_accuracy: 0.8571 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.6933 - val_f1_score: 0.0000e+00
# Epoch 41/50
# 359/359 [==============================] - 43s 120ms/step - loss: 1.7733 - accuracy: 0.8571 - precision: 0.3684 - recall: 3.0477e-04 - auc: 0.6771 - f1_score: 5.9996e-04 - val_loss: 1.7525 - val_accuracy: 0.8571 - val_precision: 0.3333 - val_recall: 1.7419e-04 - val_auc: 0.6933 - val_f1_score: 3.4188e-04
# Epoch 42/50
# 359/359 [==============================] - 44s 123ms/step - loss: 1.7727 - accuracy: 0.8572 - precision: 0.5385 - recall: 9.1432e-04 - auc: 0.6772 - f1_score: 0.0018 - val_loss: 1.7438 - val_accuracy: 0.8571 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7000 - val_f1_score: 0.0000e+00
# Epoch 43/50
# 359/359 [==============================] - 44s 123ms/step - loss: 1.7712 - accuracy: 0.8572 - precision: 0.5366 - recall: 9.5785e-04 - auc: 0.6787 - f1_score: 0.0019 - val_loss: 1.7458 - val_accuracy: 0.8572 - val_precision: 1.0000 - val_recall: 5.2256e-04 - val_auc: 0.6973 - val_f1_score: 0.0010
# Epoch 44/50
# 359/359 [==============================] - 44s 121ms/step - loss: 1.7717 - accuracy: 0.8571 - precision: 0.4828 - recall: 0.0012 - auc: 0.6787 - f1_score: 0.0024 - val_loss: 1.7534 - val_accuracy: 0.8571 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.6926 - val_f1_score: 0.0000e+00
# Epoch 45/50
# 359/359 [==============================] - 43s 119ms/step - loss: 1.7712 - accuracy: 0.8571 - precision: 0.3448 - recall: 4.3539e-04 - auc: 0.6786 - f1_score: 8.5708e-04 - val_loss: 1.7642 - val_accuracy: 0.8571 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.6859 - val_f1_score: 0.0000e+00
# Epoch 46/50
# 359/359 [==============================] - 45s 124ms/step - loss: 1.7703 - accuracy: 0.8572 - precision: 0.5741 - recall: 0.0013 - auc: 0.6792 - f1_score: 0.0027 - val_loss: 1.7845 - val_accuracy: 0.8572 - val_precision: 1.0000 - val_recall: 3.4837e-04 - val_auc: 0.6747 - val_f1_score: 6.8376e-04
# Epoch 47/50
# 359/359 [==============================] - 44s 122ms/step - loss: 1.7691 - accuracy: 0.8571 - precision: 0.4545 - recall: 0.0011 - auc: 0.6801 - f1_score: 0.0021 - val_loss: 1.7406 - val_accuracy: 0.8571 - val_precision: 0.5000 - val_recall: 1.7419e-04 - val_auc: 0.7003 - val_f1_score: 3.4188e-04
# Epoch 48/50
# 359/359 [==============================] - 46s 128ms/step - loss: 1.7703 - accuracy: 0.8572 - precision: 0.5667 - recall: 7.4016e-04 - auc: 0.6799 - f1_score: 0.0015 - val_loss: 1.7491 - val_accuracy: 0.8571 - val_precision: 0.5000 - val_recall: 3.4837e-04 - val_auc: 0.6956 - val_f1_score: 6.8376e-04
# Epoch 49/50
# 359/359 [==============================] - 44s 121ms/step - loss: 1.7672 - accuracy: 0.8572 - precision: 0.6087 - recall: 0.0012 - auc: 0.6815 - f1_score: 0.0024 - val_loss: 1.7457 - val_accuracy: 0.8571 - val_precision: 0.4828 - val_recall: 0.0024 - val_auc: 0.6981 - val_f1_score: 0.0048
# Epoch 50/50
# 359/359 [==============================] - 42s 118ms/step - loss: 1.7684 - accuracy: 0.8571 - precision: 0.4603 - recall: 0.0013 - auc: 0.6804 - f1_score: 0.0025 - val_loss: 1.7484 - val_accuracy: 0.8574 - val_precision: 0.5849 - val_recall: 0.0054 - val_auc: 0.6984 - val_f1_score: 0.0105

# %%
test_dataset

# %%
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns
import numpy
def check_model_performance(model, testing_data):
    y_true_labels = test_dataset.classes
    y_pred_labels = y_true_labels
    class_names = list(test_dataset.class_indices.keys())
    report = classification_report(y_true_labels, y_pred_labels, target_names=class_names)
    print(report)

    cm = confusion_matrix(y_true_labels, y_pred_labels)

    plt.figure(figsize = (7, 4))

    sns.heatmap(cm, annot = True,  fmt = '.0f')

    plt.ylabel('Actual')
    plt.title("Performance of FER with Optimal Model")
    plt.xlabel('Predicted')

    plt.show();

# %%
check_model_performance(model,test_dataset)
# Out:
#               precision    recall  f1-score   support
#
#        angry       0.85      0.92      0.88       724
#      disgust       0.84      0.88      0.86       712
#         fear       0.84      0.89      0.86       718
#        happy       0.86      0.88      0.87       680
#      neutral       0.84      0.87      0.86       821
#          sad       0.95      0.89      0.92      1993
#     surprise       0.93      0.89      0.91      1530
#
#     accuracy                           0.89      7178
#    macro avg       0.87      0.89      0.88      7178
# weighted avg       0.89      0.89      0.89      7178
